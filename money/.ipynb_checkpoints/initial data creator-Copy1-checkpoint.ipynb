# %%
import pandas as pd
import numpy as np
import yfinance as yf
import sys
import requests
import urllib
import time
import datetime
import threading
import queue

# %%
pd.options.mode.chained_assignment = 'raise'

# %%
# Use the following site to get list of all publicly traded Stocks
#http://nxcoreapi.com/symbols.php

#nyse
nyse = pd.read_html('http://nxcoreapi.com/symbols.php?search=&m_exchange=NYSE&m_type=&s_type=exact&m_symbol=on&m_name=on')
#nasdaq
nqnm = pd.read_html('http://nxcoreapi.com/symbols.php?search=&m_exchange=NQNM&m_type=&s_type=exact&m_symbol=on&m_name=on')
#amex
amex = pd.read_html('http://nxcoreapi.com/symbols.php?search=&m_exchange=AMEX&m_type=&s_type=exact&m_symbol=on&m_name=on')

# %%
nyse = nyse[0]
nyse.columns = nyse.iloc[0]
nyse = nyse[1:]
# nyse

# %%
nqnm = nqnm[0]
nqnm.columns = nqnm.iloc[0]
nqnm = nqnm[1:]
# nqnm

# %%
amex = amex[0]
amex.columns = amex.iloc[0]
amex = amex[1:]
# amex

# %%
stocks = nyse.copy()
stocks = stocks.append(nqnm)
stocks = stocks.append(amex)
# stocks.tail()
# stocks

# %%
stocks = stocks[['Symbol', 'Name', 'Exchange']]
stocks.reset_index(inplace=True)
stocks = stocks.drop(columns=['index'])
stocks
# Out:
# 0        Symbol                                               Name Exchange
# 0             A                          Agilent Technologies, Inc     NYSE
# 1            AA                                         Alcoa Corp     NYSE
# 2           AAN                                       Aaron's, Inc     NYSE
# 3           AAP                        Advance Auto Parts, Inc W/I     NYSE
# 4           AAT                         American Assets Trust, Inc     NYSE
# ...         ...                                                ...      ...
# 6284       YCBD                                        cbdMD, Inc.     AMEX
# 6285  YCBD.PR.A  cbdMD, Inc. 8.0% Series A Cumulative Convertib...     AMEX
# 6286       YUMA                                   Yuma Energy, Inc     AMEX
# 6287       ZDGE                                         Zedge, Inc     AMEX
# 6288        ZOM                      Zomedica Pharmaceuticals Corp     AMEX
#
# [6289 rows x 3 columns]

# %%
features = ['industry', 'sector', 'dividendRate', 'exDividendDate', 'lastSplitDate', 'lastSplitFactor']
    
for feature in features:
    stocks.loc[:, feature] = np.nan
    
stocks[features] = stocks[features].astype('object')

# %%
# symbol = yf.Ticker('A')
# symbol.info
# symbol.quarterly_financials

# %%
# new_stocks = stocks[~stocks.Symbol.str.contains('/')==True]
# # stocks = stocks[~stocks.Symbol.str.contains['/']]
# new_stocks

# %%
# uncomment the following when debugging
stocks = stocks[0:100]
stocks
# Out:
# 0     Symbol                                               Name Exchange  \
# 0          A                          Agilent Technologies, Inc     NYSE
# 1         AA                                         Alcoa Corp     NYSE
# 2        AAN                                       Aaron's, Inc     NYSE
# 3        AAP                        Advance Auto Parts, Inc W/I     NYSE
# 4        AAT                         American Assets Trust, Inc     NYSE
# ..       ...                                                ...      ...
# 95  AHT.PR.I            Ashford Hospitality Trust, Inc PR SER I     NYSE
# 96        AI                         Arlington Asset Investment     NYSE
# 97   AI.PR.B                 Arlington Asset Investment Corp PR     NYSE
# 98   AI.PR.C  Arlington Asset Investment Corp 8.250% Series ...     NYSE
# 99       AIC                    Arlington Asset Investment Corp     NYSE
#
# 0  industry sector dividendRate exDividendDate lastSplitDate lastSplitFactor
# 0       NaN    NaN          NaN            NaN           NaN             NaN
# 1       NaN    NaN          NaN            NaN           NaN             NaN
# 2       NaN    NaN          NaN            NaN           NaN             NaN
# 3       NaN    NaN          NaN            NaN           NaN             NaN
# 4       NaN    NaN          NaN            NaN           NaN             NaN
# ..      ...    ...          ...            ...           ...             ...
# 95      NaN    NaN          NaN            NaN           NaN             NaN
# 96      NaN    NaN          NaN            NaN           NaN             NaN
# 97      NaN    NaN          NaN            NaN           NaN             NaN
# 98      NaN    NaN          NaN            NaN           NaN             NaN
# 99      NaN    NaN          NaN            NaN           NaN             NaN
#
# [100 rows x 9 columns]

# %%
# gets the future and previous quarterly earnings 
def getQuarterlyDates(symbol):
    j = 0
    for connection_tries in range(5):
        try:
            url_string = 'https://finance.yahoo.com/calendar/earnings/?day=2020-06-30&symbol=' + symbol
#             print (url_string)
            dt = pd.read_html(url_string)[0].copy()
            
            # check to see if there's a future quarterly earnings date posted.  Sometimes there are more than 1.
            # They are in descending order so we loop until we find the last future one.
            future_earnings_date_index = 0
            i = -1
            for row in dt.itertuples():
                if row[6] == '-':
                    i+=1
                    next_earnings_date_index = i
                else:
                    break
            
            if i != -1:
                future_date_string = dt['Earnings Date'].iloc[next_earnings_date_index]
                future_date_object = datetime.datetime.strptime(future_date_string, "%b %d, %Y, %H %p%Z")
            else:
                future_date_object = np.nat
            
            previous_date_string = dt['Earnings Date'].iloc[next_earnings_date_index+1]
            previous_date_object = datetime.datetime.strptime(previous_date_string, "%b %d, %Y, %H %p%Z")
            # yahoo returns some dates in the future, I have no clue how many per symbol, so I just drop them.

            # get the most recent date and convert it to a date object
            
            return previous_date_object, future_date_object
        
        except (urllib.error.HTTPError, requests.exceptions.ConnectionError) as e:
            
            if connection_tries < 1:
                print (e, "HTTP Error. Will try again in 10 seconds")
                time.sleep(10)
                connection_tries +=1
            elif connection_tries < 2:
                print (e, "HTTP Error. Will try again in 30 seconds")
                time.sleep(30)
                connection_tries +=1
            elif connection_tries < 4:
                print (e, "HTTP Error. Will try again in 5 minutes")
                time.sleep(300)
                connection_tries +=1
            elif connection_tries < 5:
                print (e, "HTTP Error.  Will try again in 1 hour")
                time.sleep(3600)
                connection_tries +=1
            else:
                print (e, "HTTP Error.  Giving up.")
                
        except:
            e = sys.exc_info()[0]
#             print('here: ', e)
           
    print(symbol, e)       
    return np.nan, np.nan

# %%
def getInfo(symbol, info=True, calendar=True, quarterly_financials=True):
    connection_tries=0
    j=0
    
    info = {}
    ticker = yf.Ticker(symbol)           
    info_bool = False
    while 1:
        
        try:
            if info_bool == False:
                info = ticker.info
                info_bool = True
                           
            return info
            
        except (urllib.error.HTTPError, requests.exceptions.ConnectionError) as e:
            
            if connection_tries < 1:
                print (e, "HTTP Error. Will try again in 10 seconds")
                time.sleep(10)
                connection_tries +=1
            elif connection_tries < 2:
                print (e, "HTTP Error. Will try again in 30 seconds")
                time.sleep(30)
                connection_tries +=1
            elif connection_tries < 4:
                print (e, "HTTP Error. Will try again in 5 minutes")
                time.sleep(300)
                connection_tries +=1
            elif connection_tries < 5:
                print (e, "HTTP Error.  Will try again in 1 hour")
                time.sleep(3600)
                connection_tries +=1
            else:
                connection_tries = 0
                print (e, "HTTP Error.  Giving up.")
                return {}, pd.DataFrame(), pd.DataFrame()
        except:
            e = sys.exc_info()[0]
#             print('here: ', e)
            if j>2:
                return 'error'
            j+=1

# %%
@storeInQueue
def quarterly_thread(stocks):
    i = 0
    initial_time = round(time.time())
            
    for row in stocks.itertuples():
        print ("Quarterly Thread: ", i)    
    
        if i % 100 == 0:
            print ("It has been: ", (round(time.time())-initial_time)/ 60.0, " minutes in quarterly thread")
        
        if not '.' in row[1] and not '/' in row[1]:
        
            symbol = row[1]    

            previous, future = getQuarterlyDates(symbol)

            #     get any upcoming earnings date
            try:                
                stocks.at[i, 'upcoming_earnings_date'] = future
            except:
                stocks.at[i, 'upcoming_earnings_date'] = np.nan

            #get the previous quarterly earnings date
            try:
                stocks.at[i, 'previous_earnings_date'] = previous
            except:
                stocks.at[i, 'previous_earnings_date'] = np.nan
        else:
            print ('Bad symbol in ', row[1])
        i += 1
        
    print ('Finished quarterly thread in ', (round(time.time())-initial_time)/ 60.0, " minutes!")
    return stocks[['previous_earnings_date', 'upcoming_earnings_date']]

# %%
@storeInQueue
def info_thread(stocks, features):
    i = 0
    initial_time = round(time.time())

    bad_symbols = []
    symbols_with_no_return = []

    for row in stocks.itertuples():
        print ("Info Thread: ", i)    
        if i % 100 == 0:
            print ("It has been: ", (round(time.time())-initial_time)/ 60.0, " minutes in info thread")
        if '/' in row[1]:
            print ('Bad symbol in ', row[1])
            bad_symbols.append(i)
        elif '.' in row[1]:
            print ('Bad symbol in ', row[1])
            bad_symbols.append(i)
        else:

            symbol = row[1]
    #         symbol = yf.Ticker(symbol)           

            info = getInfo(symbol)

            if info == 'error':
                symbols_with_no_return.append(row[1])
                print('No return: ', row[1])

            else:

                for feature in features:

                    #try twice in case there's a fail that shouldn't happen

                    try:
                        value = info[feature]
                        stocks.at[i, feature] = value

                    except:
                        stocks.at[i, feature] = np.nan
                        e = sys.exc_info()[0]
                        print(e, ": ", feature) 
        i += 1
    print ('Finished info thread in ', (round(time.time())-initial_time)/ 60.0, " minutes!")
    return stocks[features]

# %%
def storeInQueue(f):
    def wrapper(*args):
        my_queue.put(f(*args))
    return wrapper

# %%
my_queue = queue.Queue()

t1 = threading.Thread(target=info_thread, args=(stocks.copy(), features,))
t1.start()

t2 = threading.Thread(target=quarterly_thread, args=(stocks.copy(),))
t2.start()

t1.join()
t2.join()
# Out:
# Info Thread:  0
# It has been:  0.0  minutes in info thread
# Quarterly Thread:  0
# It has been:  0.0  minutes in quarterly thread
# Quarterly Thread:  1
# Quarterly Thread:  2
# Info Thread:  1
# Quarterly Thread:  3
# Info Thread:  2
# Quarterly Thread:  4
# Quarterly Thread:  5
# Info Thread:  3
# Info Thread:  4
# Info Thread:  5
# AB <class 'AttributeError'>
# Quarterly Thread:  6
# Info Thread:  6
# Info Thread:  7
# ABB <class 'AttributeError'>
# Quarterly Thread:  7
# Quarterly Thread:  8
# Info Thread:  8
# Quarterly Thread:  9
# Info Thread:  9
# Info Thread:  10
# ABEV <class 'AttributeError'>
# Quarterly Thread:  10
# Quarterly Thread:  11
# Info Thread:  11
# Quarterly Thread:  12
# Quarterly Thread:  13
# Bad symbol in  ABR.PR.A
# Quarterly Thread:  14
# Bad symbol in  ABR.PR.B
# Quarterly Thread:  15
# Bad symbol in  ABR.PR.C
# Quarterly Thread:  16
# Info Thread:  12
# Quarterly Thread:  17
# Info Thread:  13
# Bad symbol in  ABR.PR.A
# Info Thread:  14
# Bad symbol in  ABR.PR.B
# Info Thread:  15
# Bad symbol in  ABR.PR.C
# Info Thread:  16
# Info Thread:  17
# AC <class 'IndexError'>
# Quarterly Thread:  18
# Quarterly Thread:  19
# Info Thread:  18
# Info Thread:  19
# ACB <class 'AttributeError'>
# Quarterly Thread:  20
# Quarterly Thread:  21
# Info Thread:  20
# Quarterly Thread:  22
# Quarterly Thread:  23
# Bad symbol in  ACEL.WS
# Quarterly Thread:  24
# Info Thread:  21
# Quarterly Thread:  25
# Info Thread:  22
# Info Thread:  23
# Bad symbol in  ACEL.WS
# Info Thread:  24
# ACI <class 'AttributeError'>
# Quarterly Thread:  26
# Quarterly Thread:  27
# Info Thread:  25
# Quarterly Thread:  28
# Bad symbol in  ACND.U
# Quarterly Thread:  29
# Info Thread:  26
# Info Thread:  27
# Info Thread:  28
# Bad symbol in  ACND.U
# Info Thread:  29
# ACP <class 'ValueError'>
# Quarterly Thread:  30
# Quarterly Thread:  31
# No return:  ACP
# Info Thread:  30
# Info Thread:  31
# ACV <class 'ValueError'>
# Quarterly Thread:  32
# Quarterly Thread:  33
# Info Thread:  32
# Info Thread:  33
# Info Thread:  34
# Info Thread:  35
# ADCT <class 'AttributeError'>
# Quarterly Thread:  34
# Quarterly Thread:  35
# Info Thread:  36
# Info Thread:  37
# Quarterly Thread:  36
# Quarterly Thread:  37
# Info Thread:  38
# Info Thread:  39
# Info Thread:  40
# Quarterly Thread:  38
# Quarterly Thread:  39
# No return:  AEB
# Info Thread:  41
# Info Thread:  42
# ADX <class 'IndexError'>
# Quarterly Thread:  40
# No return:  AEFC
# Info Thread:  43
# AEB <class 'ValueError'>
# Quarterly Thread:  41
# Info Thread:  44
# Quarterly Thread:  42
# Info Thread:  45
# Bad symbol in  AEL.PR.A
# Info Thread:  46
# Bad symbol in  AEL.PR.B
# Info Thread:  47
# Info Thread:  48
# AEFC <class 'ValueError'>
# Quarterly Thread:  43
# Info Thread:  49
# Quarterly Thread:  44
# Quarterly Thread:  45
# Bad symbol in  AEL.PR.A
# Quarterly Thread:  46
# Bad symbol in  AEL.PR.B
# Quarterly Thread:  47
# Info Thread:  50
# Bad symbol in  AEP.PR.B
# Info Thread:  51
# Bad symbol in  AEP.PR.C
# Info Thread:  52
# Info Thread:  53
# AEM <class 'AttributeError'>
# Quarterly Thread:  48
# Info Thread:  54
# Quarterly Thread:  49
# Quarterly Thread:  50
# Bad symbol in  AEP.PR.B
# Quarterly Thread:  51
# Bad symbol in  AEP.PR.C
# Quarterly Thread:  52
# Info Thread:  55
# Quarterly Thread:  53
# Quarterly Thread:  54
# No return:  AFC
# Info Thread:  56
# AFB <class 'IndexError'>
# Quarterly Thread:  55
# Info Thread:  57
# AFC <class 'ValueError'>
# Quarterly Thread:  56
# Quarterly Thread:  57
# No return:  AFGB
# Info Thread:  58
# <class 'KeyError'> :  industry
# <class 'KeyError'> :  sector
# Info Thread:  59
# Info Thread:  60
# AFGB <class 'ValueError'>
# Quarterly Thread:  58
# No return:  AFGH
# Info Thread:  61
# AFGC <class 'ValueError'>
# Quarterly Thread:  59
# Info Thread:  62
# Info Thread:  63
# Info Thread:  64
# AFGD <class 'AttributeError'>
# Quarterly Thread:  60
# Info Thread:  65
# Info Thread:  66
# Info Thread:  67
# Info Thread:  68
# AFGH <class 'ValueError'>
# Quarterly Thread:  61
# Info Thread:  69
# Bad symbol in  AGM.A
# Info Thread:  70
# Bad symbol in  AGM.PR.A
# Info Thread:  71
# Bad symbol in  AGM.PR.C
# Info Thread:  72
# Bad symbol in  AGM.PR.D
# Info Thread:  73
# Bad symbol in  AGM.PR.E
# Info Thread:  74
# Bad symbol in  AGM.PR.F
# Info Thread:  75
# Quarterly Thread:  62
# Quarterly Thread:  63
# No return:  AGN
# Info Thread:  76
# Info Thread:  77
# Bad symbol in  AGO.PR.B
# Info Thread:  78
# Bad symbol in  AGO.PR.E
# Info Thread:  79
# Bad symbol in  AGO.PR.F
# Info Thread:  80
# AFT <class 'ValueError'>
# Quarterly Thread:  64
# Info Thread:  81
# Info Thread:  82
# AG <class 'ValueError'>
# Quarterly Thread:  65
# Quarterly Thread:  66
# Info Thread:  83
# Info Thread:  84
# Info Thread:  85
# Info Thread:  86
# Bad symbol in  AHH.PR.A
# Info Thread:  87
# Bad symbol in  AHL.PR.C
# Info Thread:  88
# Bad symbol in  AHL.PR.D
# Info Thread:  89
# Bad symbol in  AHL.PR.E
# Info Thread:  90
# Info Thread:  91
# Bad symbol in  AHT.PR.D
# Info Thread:  92
# Bad symbol in  AHT.PR.F
# Info Thread:  93
# Bad symbol in  AHT.PR.G
# Info Thread:  94
# Bad symbol in  AHT.PR.H
# Info Thread:  95
# Bad symbol in  AHT.PR.I
# Info Thread:  96
# AGD <class 'ValueError'>
# Quarterly Thread:  67
# Info Thread:  97
# Bad symbol in  AI.PR.B
# Info Thread:  98
# Bad symbol in  AI.PR.C
# Info Thread:  99
# AGI <class 'ValueError'>
# Quarterly Thread:  68
# Quarterly Thread:  69
# Bad symbol in  AGM.A
# Quarterly Thread:  70
# Bad symbol in  AGM.PR.A
# Quarterly Thread:  71
# Bad symbol in  AGM.PR.C
# Quarterly Thread:  72
# Bad symbol in  AGM.PR.D
# Quarterly Thread:  73
# Bad symbol in  AGM.PR.E
# Quarterly Thread:  74
# Bad symbol in  AGM.PR.F
# Quarterly Thread:  75
# Quarterly Thread:  76
# No return:  AIC
# Finished info thread in  6.633333333333334  minutes!
# Quarterly Thread:  77
# Bad symbol in  AGO.PR.B
# Quarterly Thread:  78
# Bad symbol in  AGO.PR.E
# Quarterly Thread:  79
# Bad symbol in  AGO.PR.F
# Quarterly Thread:  80
# Quarterly Thread:  81
# Quarterly Thread:  82
# AGS <class 'AttributeError'>
# Quarterly Thread:  83
# Quarterly Thread:  84
# Quarterly Thread:  85
# Quarterly Thread:  86
# Bad symbol in  AHH.PR.A
# Quarterly Thread:  87
# Bad symbol in  AHL.PR.C
# Quarterly Thread:  88
# Bad symbol in  AHL.PR.D
# Quarterly Thread:  89
# Bad symbol in  AHL.PR.E
# Quarterly Thread:  90
# Quarterly Thread:  91
# Bad symbol in  AHT.PR.D
# Quarterly Thread:  92
# Bad symbol in  AHT.PR.F
# Quarterly Thread:  93
# Bad symbol in  AHT.PR.G
# Quarterly Thread:  94
# Bad symbol in  AHT.PR.H
# Quarterly Thread:  95
# Bad symbol in  AHT.PR.I
# Quarterly Thread:  96
# AI <class 'AttributeError'>
# Quarterly Thread:  97
# Bad symbol in  AI.PR.B
# Quarterly Thread:  98
# Bad symbol in  AI.PR.C
# Quarterly Thread:  99
# AIC <class 'ValueError'>
# Finished quarterly thread in  7.9  minutes!

# %%
my_list = []
while not my_queue.empty():
    my_list.append(my_queue.get())

# %%
stocks = stocks.copy()

for item in my_list:
    print(type(item))
    if 'previous_earnings_date' in item.columns:
        stocks[['previous_earnings_date', 'upcoming_earnings_date']] = item[['previous_earnings_date', 'upcoming_earnings_date']].copy()
    else:
        stocks[features] = item[features].copy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
stocks.head(20)
# Out:
# 0     Symbol                                Name Exchange  \
# 0          A           Agilent Technologies, Inc     NYSE
# 1         AA                          Alcoa Corp     NYSE
# 2        AAN                        Aaron's, Inc     NYSE
# 3        AAP         Advance Auto Parts, Inc W/I     NYSE
# 4        AAT          American Assets Trust, Inc     NYSE
# 5         AB  AllianceBernstein Holding LP Units     NYSE
# 6        ABB                             ABB Ltd     NYSE
# 7       ABBV                         AbbVie, Inc     NYSE
# 8        ABC              AmerisourceBergen Corp     NYSE
# 9       ABEV                        Ambev SA ADS     NYSE
# 10       ABG        Asbury Automotive Group, Inc     NYSE
# 11       ABM                 ABM Industries, Inc     NYSE
# 12       ABR                  Arbor Realty Trust     NYSE
# 13  ABR.PR.A        Arbor Realty Trust, Inc PR A     NYSE
# 14  ABR.PR.B        Arbor Realty Trust, Inc PR B     NYSE
# 15  ABR.PR.C        Arbor Realty Trust, Inc PR C     NYSE
# 16       ABT                 Abbott Laboratories     NYSE
# 17        AC       Associated Capital Group, Inc     NYSE
# 18       ACA                         Arcosa, Inc     NYSE
# 19       ACB                Aurora Cannabis, Inc     NYSE
#
# 0                                 industry              sector dividendRate  \
# 0                   Diagnostics & Research          Healthcare         0.72
# 1                                 Aluminum     Basic Materials         None
# 2                Rental & Leasing Services         Industrials         0.16
# 3                         Specialty Retail   Consumer Cyclical            1
# 4                         REIT—Diversified         Real Estate            1
# 5                         Asset Management  Financial Services         2.44
# 6             Electrical Equipment & Parts         Industrials         0.83
# 7               Drug Manufacturers—General          Healthcare         4.72
# 8                     Medical Distribution          Healthcare         1.68
# 9                        Beverages—Brewers  Consumer Defensive         0.12
# 10                Auto & Truck Dealerships   Consumer Cyclical         None
# 11             Specialty Business Services         Industrials         0.74
# 12                           REIT—Mortgage         Real Estate         1.24
# 13                                     NaN                 NaN          NaN
# 14                                     NaN                 NaN          NaN
# 15                                     NaN                 NaN          NaN
# 16                         Medical Devices          Healthcare         1.44
# 17                         Capital Markets  Financial Services          0.2
# 18               Infrastructure Operations         Industrials          0.2
# 19  Drug Manufacturers—Specialty & Generic          Healthcare         None
#
# 0  exDividendDate lastSplitDate lastSplitFactor previous_earnings_date  \
# 0      1593388800    1414972800       1398:1000    2020-08-18 12:00:00
# 1            None    1477958400        1000:801    2020-07-15 12:00:00
# 2      1600214400    1271376000             3:2    2020-07-29 12:00:00
# 3      1600300800    1127692800             3:2    2020-08-18 12:00:00
# 4      1599609600          None            None    2020-07-28 12:00:00
# 5      1596153600     891561600             2:1                    NaT
# 6      1585526400     985824000             4:1                    NaT
# 7      1594684800          None            None    2020-07-31 12:00:00
# 8      1597363200    1245110400             2:1    2020-08-05 12:00:00
# 9      1576800000    1384128000             5:1                    NaT
# 10     1217376000    1245110400             1:2    2020-07-28 12:00:00
# 11     1593561600    1020729600             2:1    2020-06-17 12:00:00
# 12     1597363200    1346284800            10:1    2020-07-31 12:00:00
# 13            NaN           NaN             NaN                    NaT
# 14            NaN           NaN             NaN                    NaT
# 15            NaN           NaN             NaN                    NaT
# 16     1594684800    1357084800      10000:4798    2020-07-16 12:00:00
# 17     1592179200    1595980800       1005:1000                    NaT
# 18     1594684800          None            None    2020-07-30 12:00:00
# 19           None    1589155200            1:12                    NaT
#
# 0  upcoming_earnings_date
# 0     2020-11-23 05:00:00
# 1     2020-10-14 06:00:00
# 2     2020-11-02 06:00:00
# 3     2020-11-10 09:00:00
# 4     2020-10-27 04:00:00
# 5                     NaT
# 6                     NaT
# 7     2020-10-30 08:00:00
# 8     2020-11-05 09:00:00
# 9                     NaT
# 10    2020-10-20 08:00:00
# 11    2020-09-08 04:00:00
# 12    2020-10-30 08:00:00
# 13                    NaT
# 14                    NaT
# 15                    NaT
# 16    2020-10-14 08:00:00
# 17                    NaT
# 18    2020-10-28 06:00:00
# 19                    NaT

# %%
stocks.to_csv('info.csv')

# %%
with open('bad_symbols.txt', 'w') as f:
    for s in bad_symbols:
        f.write(str(s) + "\n")
        
with open('symbols_no_return.txt', 'w') as f:
    for line in symbols_with_no_return:
        f.write(str(line) + "\n")
