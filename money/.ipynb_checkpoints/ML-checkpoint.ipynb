# %%
import pandas as pd
import numpy as np
import yfinance as yf
import sys
import datetime
from pandas.tseries.offsets import BDay
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn import metrics

# %%
train = pd.read_csv('completed_features.csv')
train  = train.drop(train.columns[0], axis = 1)
train.head()
# Out:
#   Symbol                    Name Exchange       Sector  \
# 0    DDD  3D Systems Corporation     NYSE   Technology
# 1    MMM              3M Company     NYSE  Health Care
# 2   WUBA             58.com Inc.     NYSE   Technology
# 3   EGHT                 8x8 Inc     NYSE   Technology
# 4   EGHT                 8x8 Inc   Nasdaq   Technology
#
#                                           industry  dividendRate  \
# 0          Computer Software: Prepackaged Software           NaN
# 1                       Medical/Dental Instruments          5.88
# 2  Computer Software: Programming, Data Processing           NaN
# 3                                     EDP Services           NaN
# 4                                     EDP Services           NaN
#
#    exDividendDate  lastSplitDate  lastSplitFactor  Buy  ...  \
# 0    0.000000e+00              0              0.0  0.0  ...
# 1    1.597968e+09              0              0.0  1.0  ...
# 2    0.000000e+00              0              0.0  0.0  ...
# 3    0.000000e+00              0              0.0  1.0  ...
# 4    0.000000e+00              0              0.0  1.0  ...
#
#    Exponential Moving Average  day1 day2 day3 day4 close on day 0  \
# 0                    0.789753   1.0  0.0  0.0  1.0       6.610000
# 1                    0.937332   1.0  1.0  1.0  1.0     154.959518
# 2                    0.841168   1.0  1.0  0.0  0.0      54.220001
# 3                    0.788320   0.0  0.0  0.0  0.0      16.709999
# 4                    0.788320   0.0  0.0  0.0  0.0      16.709999
#
#   close on day 1  close on day 2  close on day 3  close on day 4
# 0       6.690000        6.590000        6.590000        6.720000
# 1     156.376633      157.278427      157.853180      158.398224
# 2      54.500000       54.270000       54.040001       54.009998
# 3      16.639999       16.110001       16.420000       16.549999
# 4      16.639999       16.110001       16.420000       16.549999
#
# [5 rows x 29 columns]

# %%
train['Previous_Earnings_Date'].unique()
# Out:
# array(['2020-08-04', '2020-07-27', '2020-06-25', '2020-07-29',
#        '2020-07-20', '2020-07-28', '2020-07-21', '2020-07-15',
#        '2020-07-30', '2020-08-26', '2020-09-07', '2020-08-05',
#        '2020-06-24', '2020-06-29', '2020-07-23', '2020-08-17',
#        '2020-08-12', '2020-08-03', '2020-06-11', '2020-07-22',
#        '2020-07-14', '2020-08-19', '2020-08-28', '2020-07-16',
#        '2020-07-13', '2020-09-08', '2020-08-14', '2020-08-25',
#        '2020-08-06', '2020-08-11', '2020-08-31', '2020-08-10',
#        '2020-08-24', '2020-07-08', '2020-08-27', '2020-09-02',
#        '2020-08-07', '2020-06-23', '2020-06-02', '2020-08-20',
#        '2020-05-28', '2020-06-03', '2020-06-30', '2020-06-18',
#        '2020-07-09', '2020-09-09', '2020-09-01', '2020-09-03',
#        '2020-06-17', '2020-08-13', '2020-06-16', '2020-08-21',
#        '2020-08-18', '2020-05-29', '2020-07-01', '2020-06-01',
#        '2020-09-15', '2020-09-04', '2020-06-09', '2020-07-06',
#        '2020-07-10', '2020-06-10', '2020-07-24', '2020-06-22',
#        '2020-07-07', '2020-07-17', '2020-09-10', '2020-07-31',
#        '2020-06-15', '2020-06-12', '2020-07-02', '2020-09-14',
#        '2020-06-08', '2020-06-05', '2020-06-26', '2020-06-04'],
#       dtype=object)

# %%
train[train['Previous_Earnings_Date'] == '2020-06-04']
# Out:
#      Symbol                               Name  Exchange  Sector  industry  \
# 1613   TRCH  Torchlight Energy Resources, Inc.         2       6        82
# 1618   TPCO         Tribune Publishing Company         2       5        80
# 1699     ZI         ZoomInfo Technologies Inc.         2      11        28
#
#       dividendRate  lastSplitDate  lastSplitFactor  Buy  Sell  ...  \
# 1613           0.0              0              0.0    0     0  ...
# 1618           1.0              0              0.0    0     0  ...
# 1699           0.0              0              0.0    0     0  ...
#
#       Exponential Moving Average day1  day2  day3  day4  close on day 0  \
# 1613                    0.528767  0.0   0.0   0.0   0.0            0.37
# 1618                    0.756225  0.0   0.0   0.0   0.0            9.61
# 1699                    0.000000  0.0   0.0   0.0   0.0            0.00
#
#       close on day 1  close on day 2  close on day 3  close on day 4
# 1613            0.35            0.36            0.35            0.35
# 1618            9.50            9.31            8.89            9.51
# 1699            0.00            0.00            0.00            0.00
#
# [3 rows x 25 columns]

# %%
train = train[train['day4'].notna()]
train[train['Exponential Moving Average'].isnull()]
# Out:
#      Symbol                            Name Exchange                 Sector  \
# 22     ADCT             ADC Therapeutics SA     NYSE            Health Care
# 80     AFGD  American Financial Group, Inc.     NYSE                Finance
# 103     APG           APi Group Corporation     NYSE       Basic Industries
# 117    ARNC             Arconic Corporation     NYSE                    NaN
# 192    BDXB   Becton, Dickinson and Company     NYSE            Health Care
# ...     ...                             ...      ...                    ...
# 1672    VRM                     Vroom, Inc.   Nasdaq      Consumer Durables
# 1682   FREE        Whole Earth Brands, Inc.   Nasdaq  Consumer Non-Durables
# 1686  WTFCP  Wintrust Financial Corporation   Nasdaq                Finance
# 1699     ZI      ZoomInfo Technologies Inc.   Nasdaq             Technology
# 1713   ANVS               Annovis Bio, Inc.     AMEX            Health Care
#
#                                      industry  dividendRate  exDividendDate  \
# 22                      Major Pharmaceuticals           NaN    0.000000e+00
# 80                 Property-Casualty Insurers           NaN    0.000000e+00
# 103                Engineering & Construction           NaN    0.000000e+00
# 117                                       NaN           NaN    0.000000e+00
# 192                Medical/Dental Instruments          3.17    1.597277e+09
# ...                                       ...           ...             ...
# 1672                   Automotive Aftermarket           NaN    0.000000e+00
# 1682                          Specialty Foods           NaN    0.000000e+00
# 1686                              Major Banks          2.88    1.601424e+09
# 1699  Computer Software: Prepackaged Software           NaN    0.000000e+00
# 1713                    Major Pharmaceuticals           NaN    0.000000e+00
#
#       lastSplitDate  lastSplitFactor  Buy  ...  Exponential Moving Average  \
# 22                0              0.0  0.0  ...                         NaN
# 80                0              0.0  0.0  ...                         NaN
# 103               0              0.0  0.0  ...                         NaN
# 117               0              0.0  0.0  ...                         NaN
# 192               0              0.0  0.0  ...                         NaN
# ...             ...              ...  ...  ...                         ...
# 1672              0              0.0  0.0  ...                         NaN
# 1682              0              0.0  0.0  ...                         NaN
# 1686              0              0.0  0.0  ...                         NaN
# 1699              0              0.0  0.0  ...                         NaN
# 1713              0              0.0  0.0  ...                         NaN
#
#       day1 day2 day3 day4 close on day 0 close on day 1  close on day 2  \
# 22     0.0  0.0  0.0  0.0      49.779999      43.250000       43.000000
# 80     0.0  0.0  0.0  1.0      26.440001      26.230000       26.250000
# 103    1.0  0.0  1.0  1.0      14.430000      14.450000       14.410000
# 117    0.0  0.0  0.0  0.0      17.010000      16.750000       16.400000
# 192    0.0  1.0  1.0  1.0      58.846264      58.471638       59.447639
# ...    ...  ...  ...  ...            ...            ...             ...
# 1672   0.0  0.0  0.0  0.0            NaN            NaN             NaN
# 1682   1.0  0.0  1.0  1.0       7.490000       7.490000        7.450000
# 1686   1.0  1.0  1.0  1.0      25.700001      25.709999       25.799999
# 1699   0.0  0.0  0.0  0.0            NaN            NaN             NaN
# 1713   0.0  0.0  0.0  0.0       6.600000       6.500000        6.160000
#
#       close on day 3  close on day 4
# 22         42.299999       39.529999
# 80         26.400000       26.549999
# 103        14.680000       14.720000
# 117        16.280001       16.290001
# 192        59.240608       59.595520
# ...              ...             ...
# 1672             NaN             NaN
# 1682        7.500000        7.830000
# 1686       25.889999       25.969999
# 1699             NaN             NaN
# 1713        5.950000        5.810000
#
# [85 rows x 29 columns]

# %%
train = train.drop(columns=['exDividendDate', 'Future Earnings Date', 'Actual', 'Surprise'])

# %%
train['Previous_Earnings_Date'].unique()
# Out:
# array(['2020-08-04T00:00:00.000000000', '2020-07-27T00:00:00.000000000',
#        '2020-06-25T00:00:00.000000000', '2020-07-29T00:00:00.000000000',
#        '2020-07-20T00:00:00.000000000', '2020-07-28T00:00:00.000000000',
#        '2020-07-21T00:00:00.000000000', '2020-07-15T00:00:00.000000000',
#        '2020-07-30T00:00:00.000000000', '2020-08-26T00:00:00.000000000',
#        '2020-08-05T00:00:00.000000000', '2020-06-24T00:00:00.000000000',
#        '2020-06-29T00:00:00.000000000', '2020-07-23T00:00:00.000000000',
#        '2020-08-17T00:00:00.000000000', '2020-08-12T00:00:00.000000000',
#        '2020-08-03T00:00:00.000000000', '2020-06-11T00:00:00.000000000',
#        '2020-07-22T00:00:00.000000000', '2020-07-14T00:00:00.000000000',
#        '2020-08-19T00:00:00.000000000', '2020-08-28T00:00:00.000000000',
#        '2020-07-16T00:00:00.000000000', '2020-07-13T00:00:00.000000000',
#        '2020-08-14T00:00:00.000000000', '2020-08-25T00:00:00.000000000',
#        '2020-08-06T00:00:00.000000000', '2020-08-11T00:00:00.000000000',
#        '2020-08-31T00:00:00.000000000', '2020-08-10T00:00:00.000000000',
#        '2020-08-24T00:00:00.000000000', '2020-08-27T00:00:00.000000000',
#        '2020-09-02T00:00:00.000000000', '2020-08-07T00:00:00.000000000',
#        '2020-06-23T00:00:00.000000000', '2020-06-02T00:00:00.000000000',
#        '2020-08-20T00:00:00.000000000', '2020-06-03T00:00:00.000000000',
#        '2020-06-30T00:00:00.000000000', '2020-06-18T00:00:00.000000000',
#        '2020-09-01T00:00:00.000000000', '2020-09-03T00:00:00.000000000',
#        '2020-06-17T00:00:00.000000000', '2020-08-13T00:00:00.000000000',
#        '2020-06-16T00:00:00.000000000', '2020-08-21T00:00:00.000000000',
#        '2020-08-18T00:00:00.000000000', '2020-07-01T00:00:00.000000000',
#        '2020-09-04T00:00:00.000000000', '2020-06-09T00:00:00.000000000',
#        '2020-06-10T00:00:00.000000000', '2020-07-24T00:00:00.000000000',
#        '2020-06-22T00:00:00.000000000', '2020-07-17T00:00:00.000000000',
#        '2020-07-31T00:00:00.000000000', '2020-06-15T00:00:00.000000000',
#        '2020-06-12T00:00:00.000000000', '2020-07-02T00:00:00.000000000',
#        '2020-06-08T00:00:00.000000000', '2020-06-05T00:00:00.000000000',
#        '2020-06-26T00:00:00.000000000', '2020-06-04T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
train.columns
# Out:
# Index(['Symbol', 'Name', 'Exchange', 'Sector', 'industry', 'dividendRate',
#        'lastSplitDate', 'lastSplitFactor', 'Buy', 'Sell', 'Hold',
#        'Previous_Earnings_Date', 'Expected', 'daysSinceLastDividend', 'BBP',
#        'Exponential Moving Average', 'day1', 'day2', 'day3', 'day4',
#        'close on day 0', 'close on day 1', 'close on day 2', 'close on day 3',
#        'close on day 4'],
#       dtype='object')

# %%
train.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Symbol                          0
# Name                            0
# Exchange                        0
# Sector                         35
# industry                       35
# dividendRate                  942
# lastSplitDate                   0
# lastSplitFactor                 0
# Buy                             5
# Sell                            5
# Hold                            5
# Previous_Earnings_Date          0
# Expected                        0
# daysSinceLastDividend           0
# BBP                            36
# Exponential Moving Average     85
# day1                            0
# day2                            0
# day3                            0
# day4                            0
# close on day 0                 26
# close on day 1                 26
# close on day 2                 26
# close on day 3                 25
# close on day 4                 25
# dtype: int64

# %%
train.fillna(0, inplace=True)

# %%
# train['industry'].unique()

# %%
category_columns = ['Exchange', 'Sector', 'industry','Buy', 'Sell', 'Hold']

# %% [markdown]
# ## Basically all of the categories seem to affect the outcome at least a little ##

# %%
for column in category_columns:
    train.groupby([column, 'day4']).size().unstack().plot.bar(figsize=(10,6))

# %%
train.plot.scatter('Exponential Moving Average', 'day4', figsize=(20,6))
# Out:
# <AxesSubplot:xlabel='Exponential Moving Average', ylabel='day4'>

# %%
for column in category_columns:
    train[column] = train[column].astype('category').cat.codes

# %%
train.Expected = train.Expected.where(train.Expected != '-', 0)

# %%
train['Previous_Earnings_Date'] = train['Previous_Earnings_Date'].astype('datetime64')
train.Expected = train.Expected.astype('float64')

# %%
train['Previous_Earnings_Date'].unique()
# Out:
# array(['2020-08-04T00:00:00.000000000', '2020-07-27T00:00:00.000000000',
#        '2020-06-25T00:00:00.000000000', '2020-07-29T00:00:00.000000000',
#        '2020-07-20T00:00:00.000000000', '2020-07-28T00:00:00.000000000',
#        '2020-07-21T00:00:00.000000000', '2020-07-15T00:00:00.000000000',
#        '2020-07-30T00:00:00.000000000', '2020-08-26T00:00:00.000000000',
#        '2020-08-05T00:00:00.000000000', '2020-06-24T00:00:00.000000000',
#        '2020-06-29T00:00:00.000000000', '2020-07-23T00:00:00.000000000',
#        '2020-08-17T00:00:00.000000000', '2020-08-12T00:00:00.000000000',
#        '2020-08-03T00:00:00.000000000', '2020-06-11T00:00:00.000000000',
#        '2020-07-22T00:00:00.000000000', '2020-07-14T00:00:00.000000000',
#        '2020-08-19T00:00:00.000000000', '2020-08-28T00:00:00.000000000',
#        '2020-07-16T00:00:00.000000000', '2020-07-13T00:00:00.000000000',
#        '2020-08-14T00:00:00.000000000', '2020-08-25T00:00:00.000000000',
#        '2020-08-06T00:00:00.000000000', '2020-08-11T00:00:00.000000000',
#        '2020-08-31T00:00:00.000000000', '2020-08-10T00:00:00.000000000',
#        '2020-08-24T00:00:00.000000000', '2020-08-27T00:00:00.000000000',
#        '2020-09-02T00:00:00.000000000', '2020-08-07T00:00:00.000000000',
#        '2020-06-23T00:00:00.000000000', '2020-06-02T00:00:00.000000000',
#        '2020-08-20T00:00:00.000000000', '2020-06-03T00:00:00.000000000',
#        '2020-06-30T00:00:00.000000000', '2020-06-18T00:00:00.000000000',
#        '2020-09-01T00:00:00.000000000', '2020-09-03T00:00:00.000000000',
#        '2020-06-17T00:00:00.000000000', '2020-08-13T00:00:00.000000000',
#        '2020-06-16T00:00:00.000000000', '2020-08-21T00:00:00.000000000',
#        '2020-08-18T00:00:00.000000000', '2020-07-01T00:00:00.000000000',
#        '2020-09-04T00:00:00.000000000', '2020-06-09T00:00:00.000000000',
#        '2020-06-10T00:00:00.000000000', '2020-07-24T00:00:00.000000000',
#        '2020-06-22T00:00:00.000000000', '2020-07-17T00:00:00.000000000',
#        '2020-07-31T00:00:00.000000000', '2020-06-15T00:00:00.000000000',
#        '2020-06-12T00:00:00.000000000', '2020-07-02T00:00:00.000000000',
#        '2020-06-08T00:00:00.000000000', '2020-06-05T00:00:00.000000000',
#        '2020-06-26T00:00:00.000000000', '2020-06-04T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
#now we'll create the test set

# %%
train_ex = train[train.Previous_Earnings_Date < pd.to_datetime('2020-08-17')]
test = train[train.Previous_Earnings_Date >= pd.to_datetime('2020-08-17')]

# %%
test['Previous_Earnings_Date'].unique()
# Out:
# array(['2020-08-26T00:00:00.000000000', '2020-08-17T00:00:00.000000000',
#        '2020-08-19T00:00:00.000000000', '2020-08-28T00:00:00.000000000',
#        '2020-08-25T00:00:00.000000000', '2020-08-31T00:00:00.000000000',
#        '2020-08-24T00:00:00.000000000', '2020-08-27T00:00:00.000000000',
#        '2020-09-02T00:00:00.000000000', '2020-08-20T00:00:00.000000000',
#        '2020-09-01T00:00:00.000000000', '2020-09-03T00:00:00.000000000',
#        '2020-08-21T00:00:00.000000000', '2020-08-18T00:00:00.000000000',
#        '2020-09-04T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
train.dtypes
# Out:
# Symbol                                object
# Name                                  object
# Exchange                                int8
# Sector                                  int8
# industry                               int16
# dividendRate                         float64
# lastSplitDate                          int64
# lastSplitFactor                      float64
# Buy                                     int8
# Sell                                    int8
# Hold                                    int8
# Previous_Earnings_Date        datetime64[ns]
# Expected                             float64
# daysSinceLastDividend                float64
# BBP                                  float64
# Exponential Moving Average           float64
# day1                                 float64
# day2                                 float64
# day3                                 float64
# day4                                 float64
# close on day 0                       float64
# close on day 1                       float64
# close on day 2                       float64
# close on day 3                       float64
# close on day 4                       float64
# dtype: object

# %%
X_train = train_ex.drop(columns=['Symbol', 'Name', 'Previous_Earnings_Date', 'day1', 'day2', 'day3', 'day4',
                                'close on day 0', 'close on day 1', 'close on day 2',
                                 'close on day 3', 'close on day 4'])
X_test = test.drop(columns=['Symbol', 'Name', 'Previous_Earnings_Date', 'day1', 'day2', 'day3', 'day4',
                                'close on day 0', 'close on day 1', 'close on day 2',
                                 'close on day 3', 'close on day 4'])
y_train = train_ex['day3']
y_test = test['day3']

# %%
test['Previous_Earnings_Date'].unique()
# Out:
# array(['2020-08-26T00:00:00.000000000', '2020-08-17T00:00:00.000000000',
#        '2020-08-19T00:00:00.000000000', '2020-08-28T00:00:00.000000000',
#        '2020-08-25T00:00:00.000000000', '2020-08-31T00:00:00.000000000',
#        '2020-08-24T00:00:00.000000000', '2020-08-27T00:00:00.000000000',
#        '2020-09-02T00:00:00.000000000', '2020-08-20T00:00:00.000000000',
#        '2020-09-01T00:00:00.000000000', '2020-09-03T00:00:00.000000000',
#        '2020-08-21T00:00:00.000000000', '2020-08-18T00:00:00.000000000',
#        '2020-09-04T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
K=100
accuracies = np.zeros(K-1)
std_acc = np.zeros((K-1))
for i in range(1,K):
    knn = KNN(n_neighbors = i, algorithm='brute').fit(X_train, y_train)
    y_hat = knn.predict(X_test)
    accuracies[i-1] = metrics.accuracy_score(y_test, y_hat)
    
    std_acc[i-1]=np.std(y_hat==y_test)/np.sqrt(y_hat.shape[0])

    
k=accuracies.argmax()+1
print('The best value of k is ', k)
# Out:
# The best value of k is  50

# %%
plt.plot(range(1,K), accuracies, 'g')
plt.fill_between(range(1,K), accuracies-1*std_acc, accuracies+1*std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Nabors (K)')
plt.tight_layout()
plt.show()

# %%
knn = KNN(n_neighbors = k).fit(X_train, y_train)
y_hat = knn.predict(X_test)
print("KNN Accuracy Score: ", metrics.accuracy_score(y_test, y_hat))
print('KNN Confusion Matrix:')
print(metrics.confusion_matrix(y_test, y_hat))
print('Precision Score: ', metrics.precision_score(y_test, y_hat))
# Out:
# KNN Accuracy Score:  0.608955223880597
# KNN Confusion Matrix:
# [[ 62  81]
#  [ 50 142]]
# Precision Score:  0.6367713004484304

# %%
disp = metrics.plot_confusion_matrix(knn, X_test, y_test, display_labels=['Decreased', 'Increased'], cmap=plt.cm.Blues)
disp.ax_.set_title('KNN Confusion Matrix for Determining Stocks Growth')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression as Classifier
    
classifier = Classifier(max_iter=10000).fit(X_train, y_train)
y_hat = classifier.predict(X_test)
print("LR Accuracy Score: ", metrics.accuracy_score(y_test, y_hat))
print("LR Confusion Matrix: ")
print(metrics.confusion_matrix(y_test, y_hat))
print('Precision Score: ', metrics.precision_score(y_test, y_hat))
# Out:
# LR Accuracy Score:  0.5611940298507463
# LR Confusion Matrix:
# [[ 43 100]
#  [ 47 145]]
# Precision Score:  0.5918367346938775

# %%
disp = metrics.plot_confusion_matrix(classifier, X_test, y_test, display_labels=['Decreased', 'Increased'], cmap=plt.cm.Blues)
disp.ax_.set_title('Logistic Regression Confusion Matrix for Determining Stocks Growth')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier as Classifier
from sklearn import metrics

depth=3
min_samples=5
classifier = Classifier(max_depth=depth, min_samples_split=min_samples, random_state=1).fit(X_train, y_train)
y_hat = classifier.predict(X_test)
print("RF Accuracy Score: ", metrics.accuracy_score(y_test, y_hat))
print("RF Confusion Matrix: ")
print(metrics.confusion_matrix(y_test, y_hat))
print('Precision Score: ', metrics.precision_score(y_test, y_hat))
df = pd.DataFrame(data=classifier.feature_importances_, index=X_train.columns, columns=['coefficients'])
df.plot(kind='bar')
# Out:
# RF Accuracy Score:  0.582089552238806
# RF Confusion Matrix:
# [[ 33 110]
#  [ 30 162]]
# Precision Score:  0.5955882352941176
# <AxesSubplot:>

# %%
disp = metrics.plot_confusion_matrix(classifier, X_test, y_test, display_labels=['Decreased', 'Increased'], cmap=plt.cm.Blues)
disp.ax_.set_title('Random Forest Confusion Matrix for Determining Stocks Growth')
plt.show()

# %%
import xgboost as xgb
from sklearn import metrics
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test)
param = {
'max_depth': 6,  # the maximum depth of each tree
'eta': 0.3,  # the training step for each iteration
'silent': 1,  # logging mode - quiet
'objective': 'multi:softprob',  # error evaluation for multiclass training
'num_class': 3,
'colsample_bytree': 0.4,
'gamma':0.05}  # the number of classes that exist in this datset
num_round = 100  # the number of training iterations
bst = xgb.train(param, dtrain, num_round)
probs = bst.predict(dtest)

y_hat = probs.argmax(axis=1)
print("XGB Accuracy Score: ", metrics.accuracy_score(y_test, y_hat))
print("XGB Confusion Matrix: ")
print(metrics.confusion_matrix(y_test, y_hat))
print('Precision Score: ', metrics.precision_score(y_test, y_hat))
# Out:
# [17:39:07] WARNING: ../src/learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# XGB Accuracy Score:  0.5164179104477612
# XGB Confusion Matrix:
# [[ 50  93]
#  [ 69 123]]
# Precision Score:  0.5694444444444444

# %%
metrics.plot_confusion_matrix(dtrain, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-366-dce34c3afa62> in <module>
# ----> 1 metrics.plot_confusion_matrix(dtrain, X_test, y_test)
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/_plot/confusion_matrix.py in plot_confusion_matrix(estimator, X, y_true, labels, sample_weight, normalize, display_labels, include_values, xticks_rotation, values_format, cmap, ax)
#     215
#     216     if not is_classifier(estimator):
# --> 217         raise ValueError("plot_confusion_matrix only supports classifiers")
#     218
#     219     y_pred = estimator.predict(X)
#
# ValueError: plot_confusion_matrix only supports classifiers

# %%
from imblearn.ensemble import BalancedRandomForestClassifier as BRFC
from imblearn.ensemble import RUSBoostClassifier as Boost
boost = Boost().fit(X_train, y_train)
y_pred3 = brfc.predict(X_test)

print("XGB Accuracy Score: ", metrics.accuracy_score(y_test, y_hat))
print("XGB Confusion Matrix: ")
metrics.confusion_matrix(y_test, y_hat)
